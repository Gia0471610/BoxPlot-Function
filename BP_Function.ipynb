# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import BP_func as bp

# %%
# Load new cleaned dataset
df = pd.read_csv('googleplaystore_cleaned.csv')

# %%
bp.sns_bp_func(df, col_nm='Rating', by_nm='Category', size=(12,6), cols=['red', 'blue'],
               xlabel='App Category', ylabel='Rating', xticks=90,
               title='Ratings of Apps in Different Categories in Google Play Store')

# %%
bp.sns_bp_func(df, col_nm='Reviews', by_nm='Category', size=(12,6), 
               cols=['red', 'blue'], xlabel='App Category', ylabel='Reviews', xticks=90, 
               title='Reviews of Apps in Different Categories in Google Play Store')

# %%
bp.sns_bp_func(df, col_nm='Size', by_nm='Category', size=(12,6), 
               cols=['blue', 'pink'], xlabel='App Category', ylabel='App Size', xticks=90, 
               title='Size of Apps in Different Categories in Google Play Store')

# %%
bp.sns_bp_func(df, col_nm='Rating', by_nm='Content Rating', size=(12,6), 
               cols=['red', 'blue'], xlabel='Content Rating', ylabel='Rating', xticks=90, 
               title='Ratings of Apps by Content Rating in Google Play Store')

# %%
bp.sns_bp_func(df, col_nm='Reviews', by_nm='Content Rating', size=(12,6), 
               cols=['green', 'purple'], xlabel='Content Rating', ylabel='Reviews', xticks=90, 
               title='Reviews of Apps by Content Rating in Google Play Store')
